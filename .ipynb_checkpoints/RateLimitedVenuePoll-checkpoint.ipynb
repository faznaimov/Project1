# %%
# Dependencies
import pandas as pd
from config import CLIENT_ID, CLIENT_SECRET
import requests, json

# Path to csv
data_file = "Output/cleaned_venue_data2.csv"

# Creating DF from csv
df = pd.read_csv(data_file)

# df = df.drop_duplicates(subset='Venue ID', keep='first')
# df.reset_index(inplace = True, drop=True)

# # Blank columns in the DF
# df["Likes"]=""
# df["Rating"]=""

df.head(20)
# Out:
#    Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0     Wakefield              40.894705              -73.847201
# 1     Wakefield              40.894705              -73.847201
# 2     Wakefield              40.894705              -73.847201
# 3     Wakefield              40.894705              -73.847201
# 4     Wakefield              40.894705              -73.847201
# 5     Wakefield              40.894705              -73.847201
# 6     Wakefield              40.894705              -73.847201
# 7     Wakefield              40.894705              -73.847201
# 8     Wakefield              40.894705              -73.847201
# 9     Wakefield              40.894705              -73.847201
# 10    Wakefield              40.894705              -73.847201
# 11   Co-op City              40.874294              -73.829939
# 12   Co-op City              40.874294              -73.829939
# 13   Co-op City              40.874294              -73.829939
# 14   Co-op City              40.874294              -73.829939
# 15   Co-op City              40.874294              -73.829939
# 16   Co-op City              40.874294              -73.829939
# 17  Eastchester              40.887556              -73.827806
# 18    Fieldston              40.895437              -73.905643
# 19    Fieldston              40.895437              -73.905643
#
#                                   Venue Name                  Venue ID  \
# 0                             The Upper Room  4f57ef61e4b063a4ab675858
# 1                            Dyme Life Radio  4da63d645da3e8486b80546f
# 2                                   Par-City  4d23aea014f2b1f7740f68be
# 3                                  MY Studio  4e9cb64c49017c00c840e759
# 4                   Major League Music Group  4ee0764f0aafbb3dbab41e92
# 5                                 Wreckhouse  4d82dc4f8de9721e671f1151
# 6                              Matic Records  4efb879502d5a2b50e03c616
# 7                         Oasis HQ NightClub  5066b2d7e4b073ee75be2315
# 8                               Karma Lounge  4f349355e4b0debe1e3c6118
# 9   Emma C. Brisbane Youth Leadership Center  519beb25498eb0c55bccdd53
# 10                            Wenbley Lounge  4f9339c7e4b0532d5da3d0ab
# 11                        Dreiser Auditorium  561175b5498ea48f07080f55
# 12                          Blok Work Studio  4b809653f964a520037f30e3
# 13                           Damatrixstudios  4e97653c775be791ae1e9d01
# 14                                The Garage  4eaccfbc775bad292f2d50a5
# 15                  EMC Entertainment Center  50027b13e4b06407f72882ed
# 16                            tropics lounge  4f3f478ee4b0f13aa5d6e4a4
# 17                                   mingles  4df5455452b100c2d800d816
# 18                        Uptown Coffeehouse  4bddf2af0ee3a593dc4b2fb0
# 19                               Roma Lounge  4d8cf5ac34f2cbff56e8a7e3
#
#    Venue Category  Venue Latitude  Venue Longitude    Venue City Venue State  \
# 0     Music Venue       40.892567       -73.846406           NaN          NY
# 1     Music Venue       40.894541       -73.843266         Bronx          NY
# 2     Music Venue       40.890211       -73.847002         Bronx          NY
# 3     Music Venue       40.901926       -73.853504           NaN          NY
# 4     Music Venue       40.891367       -73.850088           NaN          NY
# 5     Music Venue       40.898510       -73.855356         Bronx          NY
# 6     Music Venue       40.899774       -73.857141         Bronx          NY
# 7       Nightclub       40.891920       -73.858484         Bronx          NY
# 8       Nightclub       40.901605       -73.850720         Bronx          NY
# 9          Lounge       40.887923       -73.853688         Bronx          NY
# 10         Lounge       40.897526       -73.859468         Bronx          NY
# 11      Jazz Club       40.876381       -73.829095         Bronx          NY
# 12    Music Venue       40.881773       -73.826736         Bronx          NY
# 13    Music Venue       40.871173       -73.836846         Bronx          NY
# 14      Nightclub       40.882165       -73.827593         Bronx          NY
# 15      Nightclub       40.868938       -73.841496         Bronx          NY
# 16      Nightclub       40.882027       -73.831324         Bronx          NY
# 17      Nightclub       40.891869       -73.829886  Mount Vernon          NY
# 18    Music Venue       40.892331       -73.905058         Bronx          NY
# 19         Lounge       40.890453       -73.902342         Bronx          NY
#
#     Likes  Rating
# 0     0.0     NaN
# 1     0.0     NaN
# 2     0.0     NaN
# 3     0.0     NaN
# 4     0.0     NaN
# 5     0.0     NaN
# 6     0.0     NaN
# 7     0.0     NaN
# 8     1.0     NaN
# 9     0.0     NaN
# 10    0.0     NaN
# 11    0.0     NaN
# 12    0.0     NaN
# 13    3.0     NaN
# 14   10.0     6.7
# 15    0.0     NaN
# 16    0.0     NaN
# 17    0.0     NaN
# 18    0.0     NaN
# 19    0.0     NaN

# %%
df.count()
# Out:
# Neighborhood              1226
# Neighborhood Latitude     1226
# Neighborhood Longitude    1226
# Venue Name                1226
# Venue ID                  1226
# Venue Category            1226
# Venue Latitude            1226
# Venue Longitude           1226
# Venue City                1106
# Venue State               1226
# Likes                      999
# Rating                     232
# dtype: int64

# %%
def venue_info(df, start_index, end_index, v=20180405):
    responses = []
    print("Beginning Data Retrieval")
    print("-------------------------------")
    
    #start_index = 0 # index from which we begin polling venue information due to rate limited
    #end_index = 0 # index at which we stop polling, or earlier if failure returned from 4sq

    for index in range(start_index, end_index):
        id = df.loc[index,"Venue ID"]
        print ('Attempting to get information for venue with id = ', id)
        
        url = f"https://api.foursquare.com/v2/venues/{id}?&v={v}&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}"
        
        response = requests.get(url)
        
        if response.status_code != 200:
            print ('Failure response from Foursquare API, breaking...')
            break
        else:
            result = response.json()['response']
            responses.append(result)
            try:
                df.loc[index,"Likes"]=result['venue']['likes']['count']
            except:
                df.loc[index,"Likes"]=0
            try:
                df.loc[index,"Rating"]=result['venue']['rating']
            except:
                df.loc[index,"Rating"]="N/A"

    print("Data Retrieval Complete")

# %%
venue_info(df, 1000, 1227,v=20180405)
# Out:
# Beginning Data Retrieval
# -------------------------------
# Attempting to get information for venue with id =  541a2977498ea40426bc8952
# Attempting to get information for venue with id =  51b25741498ec01487442ea7
# Attempting to get information for venue with id =  55fe6ca0498e700979253075
# Attempting to get information for venue with id =  4c43827a429a0f471780471e
# Attempting to get information for venue with id =  4db3bd34a86e8d270777a2e5
# Attempting to get information for venue with id =  4ec8843b0e6158baffdba5de
# Attempting to get information for venue with id =  4f0342f0b6346feaf0033b54
# Attempting to get information for venue with id =  520487ae498e0a54e3ea45bc
# Attempting to get information for venue with id =  58d5e483abc6d63cd1e4dd6e
# Attempting to get information for venue with id =  4e823347e5fad110369f9efd
# Attempting to get information for venue with id =  4e4f62007d8bd425e48f3cd8
# Attempting to get information for venue with id =  4f32cbfe19836c91c7fbae8d
# Attempting to get information for venue with id =  4bf815fb5ec320a1601488d3
# Attempting to get information for venue with id =  4d7d4a595a396dcb891d86fb
# Attempting to get information for venue with id =  4f641117e4b06cb9fae63978
# Attempting to get information for venue with id =  4a5e4a0df964a52050be1fe3
# Attempting to get information for venue with id =  4f483e69e4b01d17b98fd0ec
# Attempting to get information for venue with id =  5054f054e4b0a13302a46bb9
# Attempting to get information for venue with id =  508e6a5d64a4e59f0f5baf86
# Attempting to get information for venue with id =  4d12889a12916dcbcab3d68a
# Attempting to get information for venue with id =  4d0d9897e0b98cfa1520dd93
# Attempting to get information for venue with id =  4bd3aeb241b9ef3bebd700e6
# Attempting to get information for venue with id =  4fce8e7de4b0e3e7a46a67e5
# Attempting to get information for venue with id =  5abef6fb2c7eb93d80a401f8
# Attempting to get information for venue with id =  4ecd5145f5b9bed40e79ba0f
# Attempting to get information for venue with id =  50301995e4b07a83cbbc9610
# Attempting to get information for venue with id =  54b9f69b498e26d1ad5e6024
# Attempting to get information for venue with id =  51aacd59498ee7f310b44d20
# Attempting to get information for venue with id =  4e7d36266da18386220532a0
# Attempting to get information for venue with id =  51c3ad9d498ee0e6dc33734c
# Attempting to get information for venue with id =  51472076e4b0fd5cc9df9001
# Attempting to get information for venue with id =  4eed0ad5aa1f98ce654c735e
# Attempting to get information for venue with id =  51604ae2e4b00ffbd697ecc8
# Attempting to get information for venue with id =  4cddb6c370bba1cdcc9a5bc4
# Attempting to get information for venue with id =  4f8a5d19e4b047d84b00dd34
# Attempting to get information for venue with id =  595709a565211f66debe7512
# Attempting to get information for venue with id =  4cb946add78f4688757cb573
# Attempting to get information for venue with id =  4e60f294b61cd78087e4ce8f
# Attempting to get information for venue with id =  518452ef498ef45e539b798d
# Attempting to get information for venue with id =  4df2c15ec65bf55ee5299abf
# Attempting to get information for venue with id =  516b93b2e4b0e8d442644af4
# Attempting to get information for venue with id =  4e89a7f6823158273a4dd8dc
# Attempting to get information for venue with id =  4f7a0f81e4b06b95520125b2
# Attempting to get information for venue with id =  577d19db498e094bff983aad
# Attempting to get information for venue with id =  5026d8ace4b06553e235eba0
# Attempting to get information for venue with id =  4ed84a628231efe38cd9dc24
# Attempting to get information for venue with id =  4d9fec0a2305a35de518c2af
# Attempting to get information for venue with id =  4ce03ff869136dcb025ee2e6
# Attempting to get information for venue with id =  4ed1c4d49adf254458a156d8
# Attempting to get information for venue with id =  4c844d3b51ada1cdf3412e10
# Failure response from Foursquare API, breaking...
# Data Retrieval Complete

# %%
df.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Wakefield              40.894705              -73.847201
# 1    Wakefield              40.894705              -73.847201
# 2    Wakefield              40.894705              -73.847201
# 3    Wakefield              40.894705              -73.847201
# 4    Wakefield              40.894705              -73.847201
#
#                  Venue Name                  Venue ID Venue Category  \
# 0            The Upper Room  4f57ef61e4b063a4ab675858    Music Venue
# 1           Dyme Life Radio  4da63d645da3e8486b80546f    Music Venue
# 2                  Par-City  4d23aea014f2b1f7740f68be    Music Venue
# 3                 MY Studio  4e9cb64c49017c00c840e759    Music Venue
# 4  Major League Music Group  4ee0764f0aafbb3dbab41e92    Music Venue
#
#    Venue Latitude  Venue Longitude Venue City Venue State  Likes Rating
# 0       40.892567       -73.846406        NaN          NY    0.0    NaN
# 1       40.894541       -73.843266      Bronx          NY    0.0    NaN
# 2       40.890211       -73.847002      Bronx          NY    0.0    NaN
# 3       40.901926       -73.853504        NaN          NY    0.0    NaN
# 4       40.891367       -73.850088        NaN          NY    0.0    NaN

# %%
# Save as CSV
df.to_csv('Output/cleaned_venue_data2.csv', index = False)
