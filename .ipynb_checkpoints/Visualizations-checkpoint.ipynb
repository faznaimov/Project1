# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import scipy.stats as stats
from matplotlib import pyplot as plt

df = pd.read_csv("Output/cleaned_venue_data2.csv")
df.count()
# Out:
# Neighborhood              1226
# Neighborhood Latitude     1226
# Neighborhood Longitude    1226
# Venue Name                1226
# Venue ID                  1226
# Venue Category            1226
# Venue Latitude            1226
# Venue Longitude           1226
# Venue City                1106
# Venue State               1226
# Likes                     1225
# Rating                     216
# dtype: int64

# %%
# 1 - What are the most popular neighborhoods for music venues in Manhattan? 
# rank neighborhoods in by count of venues bar chart

grouped = df.groupby('Neighborhood')
grouped.count()
# Out:
#                     Neighborhood Latitude  Neighborhood Longitude  Venue Name  \
# Neighborhood
# Arden Heights                           1                       1           1
# Arrochar                                1                       1           1
# Astoria Heights                         4                       4           4
# Auburndale                              7                       7           7
# Bath Beach                              7                       7           7
# Bay Ridge                               4                       4           4
# Baychester                              3                       3           3
# Bayside                                 2                       2           2
# Bedford Park                           11                      11          11
# Bedford Stuyvesant                     13                      13          13
# Bellaire                                1                       1           1
# Belle Harbor                            1                       1           1
# Bellerose                               1                       1           1
# Belmont                                 2                       2           2
# Bensonhurst                            11                      11          11
# Borough Park                            7                       7           7
# Breezy Point                            1                       1           1
# Briarwood                              11                      11          11
# Brighton Beach                          9                       9           9
# Broadway Junction                       5                       5           5
# Brooklyn Heights                        1                       1           1
# Brownsville                            11                      11          11
# Bulls Head                              2                       2           2
# Bushwick                                3                       3           3
# Cambria Heights                         7                       7           7
# Canarsie                                7                       7           7
# Carroll Gardens                         1                       1           1
# Castle Hill                             1                       1           1
# Castleton Corners                       7                       7           7
# Central Harlem                          3                       3           3
# ...                                   ...                     ...         ...
# Sunnyside                               7                       7           7
# Sunnyside Gardens                       4                       4           4
# Sunset Park                            16                      16          16
# Sutton Place                            2                       2           2
# Throgs Neck                             2                       2           2
# Tottenville                             5                       5           5
# Tribeca                                 2                       2           2
# Turtle Bay                              1                       1           1
# University Heights                     22                      22          22
# Upper East Side                         3                       3           3
# Upper West Side                         6                       6           6
# Van Nest                                3                       3           3
# Vinegar Hill                            7                       7           7
# Wakefield                              11                      11          11
# Washington Heights                     13                      13          13
# Weeksville                             11                      11          11
# West Brighton                           6                       6           6
# West Farms                              8                       8           8
# Westchester Square                      5                       5           5
# Westerleigh                             1                       1           1
# Whitestone                             10                      10          10
# Williamsbridge                          9                       9           9
# Williamsburg                            5                       5           5
# Willowbrook                             1                       1           1
# Windsor Terrace                         9                       9           9
# Wingate                                19                      19          19
# Woodhaven                              11                      11          11
# Woodlawn                                2                       2           2
# Woodrow                                 6                       6           6
# Woodside                                8                       8           8
#
#                     Venue ID  Venue Category  Venue Latitude  Venue Longitude  \
# Neighborhood
# Arden Heights              1               1               1                1
# Arrochar                   1               1               1                1
# Astoria Heights            4               4               4                4
# Auburndale                 7               7               7                7
# Bath Beach                 7               7               7                7
# Bay Ridge                  4               4               4                4
# Baychester                 3               3               3                3
# Bayside                    2               2               2                2
# Bedford Park              11              11              11               11
# Bedford Stuyvesant        13              13              13               13
# Bellaire                   1               1               1                1
# Belle Harbor               1               1               1                1
# Bellerose                  1               1               1                1
# Belmont                    2               2               2                2
# Bensonhurst               11              11              11               11
# Borough Park               7               7               7                7
# Breezy Point               1               1               1                1
# Briarwood                 11              11              11               11
# Brighton Beach             9               9               9                9
# Broadway Junction          5               5               5                5
# Brooklyn Heights           1               1               1                1
# Brownsville               11              11              11               11
# Bulls Head                 2               2               2                2
# Bushwick                   3               3               3                3
# Cambria Heights            7               7               7                7
# Canarsie                   7               7               7                7
# Carroll Gardens            1               1               1                1
# Castle Hill                1               1               1                1
# Castleton Corners          7               7               7                7
# Central Harlem             3               3               3                3
# ...                      ...             ...             ...              ...
# Sunnyside                  7               7               7                7
# Sunnyside Gardens          4               4               4                4
# Sunset Park               16              16              16               16
# Sutton Place               2               2               2                2
# Throgs Neck                2               2               2                2
# Tottenville                5               5               5                5
# Tribeca                    2               2               2                2
# Turtle Bay                 1               1               1                1
# University Heights        22              22              22               22
# Upper East Side            3               3               3                3
# Upper West Side            6               6               6                6
# Van Nest                   3               3               3                3
# Vinegar Hill               7               7               7                7
# Wakefield                 11              11              11               11
# Washington Heights        13              13              13               13
# Weeksville                11              11              11               11
# West Brighton              6               6               6                6
# West Farms                 8               8               8                8
# Westchester Square         5               5               5                5
# Westerleigh                1               1               1                1
# Whitestone                10              10              10               10
# Williamsbridge             9               9               9                9
# Williamsburg               5               5               5                5
# Willowbrook                1               1               1                1
# Windsor Terrace            9               9               9                9
# Wingate                   19              19              19               19
# Woodhaven                 11              11              11               11
# Woodlawn                   2               2               2                2
# Woodrow                    6               6               6                6
# Woodside                   8               8               8                8
#
#                     Venue City  Venue State  Likes  Rating
# Neighborhood
# Arden Heights                1            1      1       0
# Arrochar                     1            1      1       0
# Astoria Heights              4            4      4       2
# Auburndale                   6            7      7       1
# Bath Beach                   7            7      7       0
# Bay Ridge                    4            4      4       1
# Baychester                   3            3      3       0
# Bayside                      2            2      2       1
# Bedford Park                 9           11     11       0
# Bedford Stuyvesant          13           13     13       2
# Bellaire                     1            1      1       0
# Belle Harbor                 1            1      1       0
# Bellerose                    1            1      1       0
# Belmont                      2            2      2       0
# Bensonhurst                  9           11     11       1
# Borough Park                 7            7      7       0
# Breezy Point                 0            1      1       0
# Briarwood                   11           11     11       0
# Brighton Beach               9            9      9       1
# Broadway Junction            5            5      5       2
# Brooklyn Heights             1            1      1       0
# Brownsville                  9           11     11       0
# Bulls Head                   2            2      2       0
# Bushwick                     3            3      3       3
# Cambria Heights              7            7      7       2
# Canarsie                     7            7      7       0
# Carroll Gardens              1            1      1       1
# Castle Hill                  1            1      1       0
# Castleton Corners            5            7      7       0
# Central Harlem               3            3      3       2
# ...                        ...          ...    ...     ...
# Sunnyside                    5            7      7       0
# Sunnyside Gardens            4            4      4       1
# Sunset Park                 15           16     16       3
# Sutton Place                 2            2      2       1
# Throgs Neck                  2            2      2       0
# Tottenville                  4            5      5       0
# Tribeca                      2            2      2       2
# Turtle Bay                   1            1      1       1
# University Heights          20           22     22       5
# Upper East Side              3            3      3       3
# Upper West Side              6            6      6       5
# Van Nest                     3            3      3       0
# Vinegar Hill                 7            7      7       1
# Wakefield                    8           11     11       0
# Washington Heights          11           13     13       3
# Weeksville                  10           11     11       1
# West Brighton                6            6      6       0
# West Farms                   8            8      8       0
# Westchester Square           4            5      5       0
# Westerleigh                  1            1      1       0
# Whitestone                   9           10     10       1
# Williamsbridge               6            9      9       1
# Williamsburg                 5            5      5       5
# Willowbrook                  1            1      1       0
# Windsor Terrace              9            9      9       3
# Wingate                     18           19     19       1
# Woodhaven                   10           11     11       2
# Woodlawn                     2            2      2       0
# Woodrow                      5            6      6       0
# Woodside                     8            8      8       3
#
# [223 rows x 11 columns]

# %%
no_missing_ratings = df[pd.to_numeric(df['Rating'], errors='coerce').notnull()]
grouped = no_missing_ratings.groupby(['Neighborhood','Venue Category']).agg({'Likes': 'sum', 'Rating': 'mean'}).reset_index()

most_likes = grouped.loc[grouped.reset_index().groupby(['Neighborhood'])['Likes'].idxmax()].sort_values(by='Likes', ascending=False)
highest_rating = grouped.loc[grouped.reset_index().groupby(['Neighborhood'])['Rating'].idxmax()].sort_values(by='Rating', ascending=False)

# %%
# 2.a - Highest rated venue category by neighborhood
highest_rating['Venue Category'].value_counts().plot.pie()
# highest_rating
# Out:
# <img src="data:image/png;base64,..." width="838.7499875016513">

# %%
sorted = grouped.sort_values(by='Likes', ascending=False)
top_20 = sorted[:20]
top_20
# Out:
#           Neighborhood Venue Category   Likes    Rating
# 88             Midtown   Concert Hall  3203.0  9.400000
# 98         Murray Hill         Lounge  2709.0  7.650000
# 20             Chelsea      Nightclub  2362.0  8.300000
# 69      Lincoln Square   Concert Hall  2347.0  9.233333
# 22           Chinatown      Rock Club  2261.0  8.450000
# 21           Chinatown         Lounge  1806.0  7.666667
# 18             Chelsea      Jazz Club  1742.0  8.600000
# 72      Lincoln Square    Opera House  1692.0  9.500000
# 19             Chelsea         Lounge  1585.0  7.800000
# 26             Clinton    Music Venue  1520.0  8.066667
# 37        East Village    Music Venue  1474.0  8.100000
# 90             Midtown      Nightclub  1419.0  8.500000
# 101         North Side    Music Venue  1359.0  9.100000
# 71      Lincoln Square    Music Venue  1301.0  7.800000
# 102         North Side    Record Shop  1276.0  9.400000
# 139    Upper West Side   Concert Hall  1243.0  9.300000
# 55   Greenwich Village      Rock Club  1102.0  8.500000
# 13     Carroll Gardens      Rock Club  1095.0  8.800000
# 25             Clinton         Lounge  1093.0  7.733333
# 149       Williamsburg    Music Venue   934.0  8.600000

# %%
# TODO: Add explanation 
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
plt.tight_layout()
top_20[['Neighborhood','Venue Category','Likes']].pivot(index='Neighborhood', columns='Venue Category', values='Likes').plot.bar(stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="857.4999872222545">

# %%
# 3 - Which neighborhoods have the most highly rated/most liked venues?

# %%
# 4 - Which music venues have the most likes/highest ratings?
