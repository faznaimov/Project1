# %%
# Dependencies
import pandas as pd
from config import CLIENT_ID, CLIENT_SECRET
import requests, json

# Path to csv
data_file = "Output/cleaned_venue_data.csv"

# Creating DF from csv
df = pd.read_csv(data_file)

# df = df.drop_duplicates(subset='Venue ID', keep='first')
# df.reset_index(inplace = True, drop=True)

# # Blank columns in the DF
# df["Likes"]=""
# df["Rating"]=""

df.head(20)
# Out:
#    Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0     Wakefield              40.894705              -73.847201
# 1     Wakefield              40.894705              -73.847201
# 2     Wakefield              40.894705              -73.847201
# 3     Wakefield              40.894705              -73.847201
# 4     Wakefield              40.894705              -73.847201
# 5     Wakefield              40.894705              -73.847201
# 6     Wakefield              40.894705              -73.847201
# 7     Wakefield              40.894705              -73.847201
# 8     Wakefield              40.894705              -73.847201
# 9     Wakefield              40.894705              -73.847201
# 10    Wakefield              40.894705              -73.847201
# 11   Co-op City              40.874294              -73.829939
# 12   Co-op City              40.874294              -73.829939
# 13   Co-op City              40.874294              -73.829939
# 14   Co-op City              40.874294              -73.829939
# 15   Co-op City              40.874294              -73.829939
# 16   Co-op City              40.874294              -73.829939
# 17  Eastchester              40.887556              -73.827806
# 18    Fieldston              40.895437              -73.905643
# 19    Fieldston              40.895437              -73.905643
#
#                                   Venue Name                  Venue ID  \
# 0                             The Upper Room  4f57ef61e4b063a4ab675858
# 1                            Dyme Life Radio  4da63d645da3e8486b80546f
# 2                                   Par-City  4d23aea014f2b1f7740f68be
# 3                                  MY Studio  4e9cb64c49017c00c840e759
# 4                   Major League Music Group  4ee0764f0aafbb3dbab41e92
# 5                                 Wreckhouse  4d82dc4f8de9721e671f1151
# 6                              Matic Records  4efb879502d5a2b50e03c616
# 7                         Oasis HQ NightClub  5066b2d7e4b073ee75be2315
# 8                               Karma Lounge  4f349355e4b0debe1e3c6118
# 9   Emma C. Brisbane Youth Leadership Center  519beb25498eb0c55bccdd53
# 10                            Wenbley Lounge  4f9339c7e4b0532d5da3d0ab
# 11                        Dreiser Auditorium  561175b5498ea48f07080f55
# 12                          Blok Work Studio  4b809653f964a520037f30e3
# 13                           Damatrixstudios  4e97653c775be791ae1e9d01
# 14                                The Garage  4eaccfbc775bad292f2d50a5
# 15                  EMC Entertainment Center  50027b13e4b06407f72882ed
# 16                            tropics lounge  4f3f478ee4b0f13aa5d6e4a4
# 17                                   mingles  4df5455452b100c2d800d816
# 18                        Uptown Coffeehouse  4bddf2af0ee3a593dc4b2fb0
# 19                               Roma Lounge  4d8cf5ac34f2cbff56e8a7e3
#
#    Venue Category  Venue Latitude  Venue Longitude    Venue City Venue State  \
# 0     Music Venue       40.892567       -73.846406           NaN          NY
# 1     Music Venue       40.894541       -73.843266         Bronx          NY
# 2     Music Venue       40.890211       -73.847002         Bronx          NY
# 3     Music Venue       40.901926       -73.853504           NaN          NY
# 4     Music Venue       40.891367       -73.850088           NaN          NY
# 5     Music Venue       40.898510       -73.855356         Bronx          NY
# 6     Music Venue       40.899774       -73.857141         Bronx          NY
# 7       Nightclub       40.891920       -73.858484         Bronx          NY
# 8       Nightclub       40.901605       -73.850720         Bronx          NY
# 9          Lounge       40.887923       -73.853688         Bronx          NY
# 10         Lounge       40.897526       -73.859468         Bronx          NY
# 11      Jazz Club       40.876381       -73.829095         Bronx          NY
# 12    Music Venue       40.881773       -73.826736         Bronx          NY
# 13    Music Venue       40.871173       -73.836846         Bronx          NY
# 14      Nightclub       40.882165       -73.827593         Bronx          NY
# 15      Nightclub       40.868938       -73.841496         Bronx          NY
# 16      Nightclub       40.882027       -73.831324         Bronx          NY
# 17      Nightclub       40.891869       -73.829886  Mount Vernon          NY
# 18    Music Venue       40.892331       -73.905058         Bronx          NY
# 19         Lounge       40.890453       -73.902342         Bronx          NY
#
#     Likes  Rating
# 0     0.0     NaN
# 1     0.0     NaN
# 2     0.0     NaN
# 3     0.0     NaN
# 4     0.0     NaN
# 5     0.0     NaN
# 6     0.0     NaN
# 7     0.0     NaN
# 8     1.0     NaN
# 9     0.0     NaN
# 10    0.0     NaN
# 11    0.0     NaN
# 12    0.0     NaN
# 13    3.0     NaN
# 14   10.0     6.7
# 15    0.0     NaN
# 16    0.0     NaN
# 17    0.0     NaN
# 18    0.0     NaN
# 19    0.0     NaN

# %%
df.count()
# Out:
# Neighborhood              1226
# Neighborhood Latitude     1226
# Neighborhood Longitude    1226
# Venue Name                1226
# Venue ID                  1226
# Venue Category            1226
# Venue Latitude            1226
# Venue Longitude           1226
# Venue City                1106
# Venue State               1226
# Likes                     1226
# Rating                    1226
# dtype: int64

# %%
def venue_info(df, start_index, end_index, v=20180405):
    responses = []
    print("Beginning Data Retrieval")
    print("-------------------------------")
    
    #start_index = 0 # index from which we begin polling venue information due to rate limited
    #end_index = 0 # index at which we stop polling, or earlier if failure returned from 4sq

    for index in range(start_index, end_index):
        id = df.loc[index,"Venue ID"]
        print ('Attempting to get information for venue with id = ', id)
        
        url = f"https://api.foursquare.com/v2/venues/{id}?&v={v}&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}"
        
        response = requests.get(url)
        
        if response.status_code != 200:
            print ('Failure response from Foursquare API, breaking...')
            break
        else:
            result = response.json()['response']
            responses.append(result)
            try:
                df.loc[index,"Likes"]=result['venue']['likes']['count']
            except:
                df.loc[index,"Likes"]=0
            try:
                df.loc[index,"Rating"]=result['venue']['rating']
            except:
                df.loc[index,"Rating"]="N/A"

    print("Data Retrieval Complete")

# %%
venue_info(df, 450, 950,v=20180405)
# Out:
# Beginning Data Retrieval
# -------------------------------
# Attempting to get information for venue with id =  4165d880f964a5207d1d1fe3
# Attempting to get information for venue with id =  4f245340e4b0e120818930b2
# Attempting to get information for venue with id =  4c438401f0bdd13a0359c8cc
# Attempting to get information for venue with id =  50c41ab2e4b01b1b6e03852d
# Attempting to get information for venue with id =  4f77e897e4b067aa3004c009
# Attempting to get information for venue with id =  5658fd6b498ea216357bb991
# Attempting to get information for venue with id =  4eed94919911d70cb80241ba
# Attempting to get information for venue with id =  502f9d7ae4b0648637b46335
# Attempting to get information for venue with id =  4e399f2614959f8577ab35d4
# Attempting to get information for venue with id =  526b274a498ec0ae630300bc
# Attempting to get information for venue with id =  4cfada0cc6cca35d5cf18832
# Attempting to get information for venue with id =  4ebf28fd5c5c3d470c77198b
# Attempting to get information for venue with id =  4d0fce377177b1f77b894d22
# Attempting to get information for venue with id =  4f4c4ce7e4b00b42c3070b9b
# Attempting to get information for venue with id =  4c72ad5c8efc3704e390137d
# Attempting to get information for venue with id =  581e699dc25d20021419bfd5
# Attempting to get information for venue with id =  4f647ef6e4b0e30d209fdf39
# Attempting to get information for venue with id =  5290ef5211d214e9ddc973da
# Attempting to get information for venue with id =  4e9a606b29c27d6ad694660a
# Attempting to get information for venue with id =  4e6c4d56b61c739ba87f84e8
# Attempting to get information for venue with id =  4eebd321a69d8afe690de9af
# Attempting to get information for venue with id =  4b613856f964a520470d2ae3
# Attempting to get information for venue with id =  4e592861aeb7d78d9f72f3e9
# Attempting to get information for venue with id =  51377e61e4b0db6be0588044
# Attempting to get information for venue with id =  50d8afd2e4b028bbdf229a27
# Attempting to get information for venue with id =  51ea14fd498e48261545c41b
# Attempting to get information for venue with id =  4e8a71ee93ad2e858a764f8d
# Attempting to get information for venue with id =  4eb4af13d3e3644ca5e8bd28
# Attempting to get information for venue with id =  5380efdd498e54e075c928c6
# Attempting to get information for venue with id =  508b5c60e4b07c9fb086c345
# Attempting to get information for venue with id =  56201dca498e940a1c55cf18
# Attempting to get information for venue with id =  51a18f44498e1d8e284a09f3
# Attempting to get information for venue with id =  4e615cbdc65b2dc89f298796
# Attempting to get information for venue with id =  4ef57c279911b01dd9f18399
# Attempting to get information for venue with id =  5605ee11498ecd0d65f8159c
# Attempting to get information for venue with id =  5531dc2f498e0d5798654877
# Attempting to get information for venue with id =  4f63d1e4e4b0bf101151c606
# Attempting to get information for venue with id =  4d8be3812146721e8277f753
# Attempting to get information for venue with id =  4e30f80ec65b93ca1a405058
# Attempting to get information for venue with id =  4b554bbff964a52009e127e3
# Attempting to get information for venue with id =  57117e2ccd10de71af009a92
# Attempting to get information for venue with id =  5708b1e4498e5b84bf8e86b3
# Attempting to get information for venue with id =  5959609409e2832a1a63e2b0
# Attempting to get information for venue with id =  4e1f8adc1495f18f033b3d9e
# Attempting to get information for venue with id =  55be90fc498e97ddb15648ce
# Attempting to get information for venue with id =  520d74e011d2c90a3649f256
# Attempting to get information for venue with id =  51e87e48498e643187ce260a
# Attempting to get information for venue with id =  4e3b3e337d8b0e96104cdb28
# Attempting to get information for venue with id =  4f7b6e82e4b076d3e6efaf33
# Attempting to get information for venue with id =  4ce5f3879f776ea869404f22
# Attempting to get information for venue with id =  4e0d01acb61c3fe477f56542
# Attempting to get information for venue with id =  4c72cbba9e706dcbdfc94b62
# Attempting to get information for venue with id =  4add1c13f964a520216421e3
# Attempting to get information for venue with id =  50c26d00e4b0e0fa33c8c821
# Attempting to get information for venue with id =  4bf0582725afb7131ada4a6f
# Attempting to get information for venue with id =  4f0d3568e4b08ead5da55143
# Attempting to get information for venue with id =  523e44ea498ed768e756bb45
# Attempting to get information for venue with id =  5132a130e4b0ed8937fe5c84
# Attempting to get information for venue with id =  4f8f7adae4b063d0a03f244a
# Attempting to get information for venue with id =  50835f3be4b05e9135234517
# Attempting to get information for venue with id =  52e468eb498e4e83b14270b2
# Attempting to get information for venue with id =  4c01aa5527dcc9283df4e052
# Attempting to get information for venue with id =  55d54036498e5d132bd7d8e9
# Attempting to get information for venue with id =  4d5b5d867103236a6c50720c
# Attempting to get information for venue with id =  56de4e9a498eaee0e7771b36
# Attempting to get information for venue with id =  551b1e5d498e1cf926a40b11
# Attempting to get information for venue with id =  4f32c3bd19836c91c7f80871
# Attempting to get information for venue with id =  4e1675a47d8b69590f430bf3
# Attempting to get information for venue with id =  4f1e986de4b0fb1c96c67011
# Attempting to get information for venue with id =  4c4a522d9c8d2d7f14cb5869
# Attempting to get information for venue with id =  4ec86c92e30071991648b021
# Attempting to get information for venue with id =  4b5a745ff964a5201bc628e3
# Attempting to get information for venue with id =  4ea9fb805c5cf8848a13a35e
# Attempting to get information for venue with id =  4dce0855183899ddfac8d7d1
# Attempting to get information for venue with id =  4c58cfc47f599521e56923ec
# Attempting to get information for venue with id =  4dc67cfeae608779d1551006
# Attempting to get information for venue with id =  5015fca5e4b0c79e48f82d6d
# Attempting to get information for venue with id =  4e84ed4893ad6f46cdd1e10d
# Attempting to get information for venue with id =  4f89a732e4b055d23029626e
# Attempting to get information for venue with id =  4edbc7160e61d46ad9adbd0c
# Attempting to get information for venue with id =  4f8c35e0e4b0e81f69ffb63f
# Attempting to get information for venue with id =  53592471498efa805acbbed8
# Attempting to get information for venue with id =  5aac6c7c9deb7d11ac181a7a
# Attempting to get information for venue with id =  4c79559c566db60c5c8a440e
# Attempting to get information for venue with id =  4f32c63b19836c91c7f91fb5
# Attempting to get information for venue with id =  5483af35498e56d019ca641c
# Attempting to get information for venue with id =  4b11ced7f964a5201b8523e3
# Attempting to get information for venue with id =  4f054eaa29c22bbefeb1b3a0
# Attempting to get information for venue with id =  4f3ca5ade4b02fa0cf66d9f9
# Attempting to get information for venue with id =  5635c121498e6204e170b20a
# Attempting to get information for venue with id =  4b815d83f964a520c1a130e3
# Attempting to get information for venue with id =  4bd10ba3046076b0cc547171
# Attempting to get information for venue with id =  462e89e4f964a520ed451fe3
# Attempting to get information for venue with id =  4ed161956da162f1bfb3aa18
# Attempting to get information for venue with id =  4f36829de4b0b0eb8c22317b
# Attempting to get information for venue with id =  4bf76b545ec320a1021787d3
# Attempting to get information for venue with id =  57145034498e41fb77d44ad7
# Attempting to get information for venue with id =  4d6ae5472bf05481857dc9ed
# Attempting to get information for venue with id =  4e86893a0aaf882b70447459
# Attempting to get information for venue with id =  4bc3f3c44cdfc9b648229821
# Attempting to get information for venue with id =  598ceccb0a464d25e378fa89
# Attempting to get information for venue with id =  4c376c7918e72d7f188216f5
# Attempting to get information for venue with id =  50ba7e84f136840c400b79d1
# Attempting to get information for venue with id =  4bddff7ee75c0f47cd7bc603
# Attempting to get information for venue with id =  4dd75447fa76ad96d122ccc5
# Attempting to get information for venue with id =  51853082498ea34fba84fce0
# Attempting to get information for venue with id =  4be56a102457a593cf6aab15
# Attempting to get information for venue with id =  500b4654e4b0e95404915439
# Attempting to get information for venue with id =  4c2cdef28ef52d7f879933ba
# Attempting to get information for venue with id =  4bd1f06ccaff9521f0afd1f0
# Attempting to get information for venue with id =  5099d8f0e4b05481a9b4975f
# Attempting to get information for venue with id =  50e9074be4b036fe52d1c74b
# Attempting to get information for venue with id =  4f77dab6e4b03b459dd609d5
# Attempting to get information for venue with id =  4ef8d886775b54cdb5a27160
# Attempting to get information for venue with id =  54b71ae0498ee54816ae89a1
# Attempting to get information for venue with id =  5b132aad6f0aa2002c3f8c5a
# Attempting to get information for venue with id =  51a22095498ef127757368d3
# Attempting to get information for venue with id =  557ce6c5498e860f860b63a3
# Attempting to get information for venue with id =  50d0103fe4b0bb470f132a64
# Attempting to get information for venue with id =  4e5e690caeb78833bb8bffd9
# Attempting to get information for venue with id =  4f94d622e4b0dcd913525fd3
# Attempting to get information for venue with id =  4f00096f77c885c335ed9d31
# Attempting to get information for venue with id =  53365942498e52d88521d6fa
# Attempting to get information for venue with id =  4d9fdde3bb206ea8a212d0fd
# Attempting to get information for venue with id =  4ce8b0bd948f224bbd4cf25d
# Attempting to get information for venue with id =  4e2a270a18508ec753d11b20
# Attempting to get information for venue with id =  4e6c5a75aeb750adf646a7dc
# Attempting to get information for venue with id =  54235799498eb6929f0b55fe
# Attempting to get information for venue with id =  4f9b6c0fe4b0b38d2edc543f
# Attempting to get information for venue with id =  5383e528498e1b7adfcdbc3f
# Attempting to get information for venue with id =  4e30215ee4cdb5a70d6f28d9
# Attempting to get information for venue with id =  51254babe4b05af5588f7896
# Attempting to get information for venue with id =  4c676b1eaebea593885f76d0
# Attempting to get information for venue with id =  4d27fded342d6dcb04edf3ca
# Attempting to get information for venue with id =  4d97f00ec19fb60c7607a465
# Attempting to get information for venue with id =  5250adfa11d2f2de3a0ab404
# Attempting to get information for venue with id =  4c65ba2aaebea593643a71d0
# Attempting to get information for venue with id =  5c85a3792619ee002c840715
# Attempting to get information for venue with id =  512fb027e4b01ed8dcdffd3c
# Attempting to get information for venue with id =  47048266f964a5204f4b1fe3
# Attempting to get information for venue with id =  59dec5ac26659b19f9deab4c
# Attempting to get information for venue with id =  4f23ba9de4b05160ae1083a8
# Attempting to get information for venue with id =  4c26d2e6136d20a10422e661
# Attempting to get information for venue with id =  4f03ab329911be1fbcbc925c
# Attempting to get information for venue with id =  4db35ce34df05e5aaaca05bf
# Attempting to get information for venue with id =  51a1d4c8498e8482f4e0bed3
# Attempting to get information for venue with id =  5280539a498e05d3a8fc97ce
# Attempting to get information for venue with id =  59046a81cad1b6166c57658e
# Attempting to get information for venue with id =  4e5321861850878f1b9727fc
# Attempting to get information for venue with id =  4b915b9ef964a520f2b533e3
# Attempting to get information for venue with id =  4e7c02e9a809dd7718a88eba
# Attempting to get information for venue with id =  4c259afea852c9281a49e56c
# Attempting to get information for venue with id =  4ca838f2d971b1f723a312e1
# Attempting to get information for venue with id =  4f1a4df6e4b035290d1ad9e4
# Attempting to get information for venue with id =  4e4b1a1714958c3abfa43dac
# Attempting to get information for venue with id =  3fd66200f964a520dbe31ee3
# Attempting to get information for venue with id =  593f0e372f97ec0681af6743
# Attempting to get information for venue with id =  4f5303dbe4b02cf6be81de21
# Attempting to get information for venue with id =  3fd66200f964a520e0e51ee3
# Attempting to get information for venue with id =  3fd66200f964a5200fe41ee3
# Attempting to get information for venue with id =  4af35807f964a520c4ec21e3
# Attempting to get information for venue with id =  4bce0803b6c49c74fd6b9691
# Attempting to get information for venue with id =  4c51fda17f6e20a1c7c5fbea
# Attempting to get information for venue with id =  460d50e2f964a52008451fe3
# Attempting to get information for venue with id =  4ec8a78b61af9e14313209d6
# Attempting to get information for venue with id =  57747010cd100bd4dbd9161e
# Attempting to get information for venue with id =  51565a78e4b0a9d4bf77ee77
# Attempting to get information for venue with id =  4db6358a4b226b343db0ba61
# Attempting to get information for venue with id =  4daa673493a04642f07fd41a
# Attempting to get information for venue with id =  500c6444e4b0e68938acc1d9
# Attempting to get information for venue with id =  4b7f7747f964a520113030e3
# Attempting to get information for venue with id =  4d7c48a7136bf04db0045d8d
# Attempting to get information for venue with id =  4ce79276f1c6236ab6795af0
# Attempting to get information for venue with id =  4c5e28586147be9a345b9409
# Attempting to get information for venue with id =  4eacbfd3775bad292f26f6a1
# Attempting to get information for venue with id =  5baecaadcbcdee002ceb3205
# Attempting to get information for venue with id =  4e3b64a4b61cb577be5c410a
# Attempting to get information for venue with id =  4f288b54e4b09023ddaacd95
# Attempting to get information for venue with id =  4b02fd24f964a520b04b22e3
# Attempting to get information for venue with id =  4ca69bdb76d3a0930b85036b
# Attempting to get information for venue with id =  5a923669f96b2c50991bc346
# Attempting to get information for venue with id =  5a37dae9bd897e22be1c05da
# Attempting to get information for venue with id =  505f79d1e4b0fd143d25ed34
# Attempting to get information for venue with id =  577c694d498e094bfe343c2d
# Attempting to get information for venue with id =  52e94d04498e1da0c4d4d4c8
# Attempting to get information for venue with id =  4f91fc43e4b04fef01131bab
# Attempting to get information for venue with id =  4fcbcd6ee4b07471e0e47a65
# Attempting to get information for venue with id =  523e6be011d2f8b343114aac
# Attempting to get information for venue with id =  4eaa3cfde3000d1f055f1ad4
# Attempting to get information for venue with id =  5136b5c9e4b02636e64fd995
# Attempting to get information for venue with id =  502de6d6e4b0d98c30857e04
# Attempting to get information for venue with id =  4aed0b8cf964a520ebcc21e3
# Attempting to get information for venue with id =  517bdc9fe4b0d88f1327d4da
# Attempting to get information for venue with id =  3fd66200f964a5206be31ee3
# Attempting to get information for venue with id =  4b7f0918f964a520e91130e3
# Attempting to get information for venue with id =  4e7c81d0149595a17e5a6b15
# Attempting to get information for venue with id =  4e7bc78f29c2e440a898a087
# Attempting to get information for venue with id =  549e1a59498e58bd4f653d19
# Attempting to get information for venue with id =  4eb2b23fe3008b29020570c7
# Attempting to get information for venue with id =  4e74fc2345ddd4323f896391
# Attempting to get information for venue with id =  4e83982a4690c0a782be1cb2
# Attempting to get information for venue with id =  531b0eec498eba29acb10240
# Attempting to get information for venue with id =  4de06214fa76425c54189c6b
# Attempting to get information for venue with id =  56d93b74498e2b1b821bfaa4
# Attempting to get information for venue with id =  4d59bdfa3358a0900e718a44
# Attempting to get information for venue with id =  4b9ad30ff964a52059d935e3
# Attempting to get information for venue with id =  4f811bafe4b0a458baadb20a
# Attempting to get information for venue with id =  514faba2e4b05bcb31082781
# Attempting to get information for venue with id =  4aa98f74f964a520465420e3
# Attempting to get information for venue with id =  4ad7edadf964a520251021e3
# Attempting to get information for venue with id =  4c5e296d9b28d13aa7e25b70
# Attempting to get information for venue with id =  4fa5a8d5e4b054830719e405
# Attempting to get information for venue with id =  4af10be5f964a520a1e021e3
# Attempting to get information for venue with id =  4dca0d2de4cde9e42f7e2400
# Attempting to get information for venue with id =  5078d6aae4b05ac93cb0c0d3
# Attempting to get information for venue with id =  4dc97e1aae60a780bb41fc93
# Attempting to get information for venue with id =  4f6f71e5e4b0ac4cdc20b577
# Attempting to get information for venue with id =  55c486fc498eaba94b5e9289
# Attempting to get information for venue with id =  4f5b24dce4b0a4baa2387b7b
# Attempting to get information for venue with id =  4e52cbf7b0fbfe59e9dbbba3
# Attempting to get information for venue with id =  522a574611d2920f04be1a74
# Attempting to get information for venue with id =  4bbb71d8f1c5ef3bf9fac814
# Attempting to get information for venue with id =  3fd66200f964a520ddea1ee3
# Attempting to get information for venue with id =  4bb3f19a0cbcef3b4686582a
# Attempting to get information for venue with id =  5255afa58bbdabf2640f3953
# Attempting to get information for venue with id =  56f09384498e87a6c82227d7
# Attempting to get information for venue with id =  4c8e7685c865952191dc0029
# Attempting to get information for venue with id =  578afbcb498ebc33f1b0826e
# Attempting to get information for venue with id =  3fd66200f964a52020e81ee3
# Attempting to get information for venue with id =  3fd66200f964a52055e81ee3
# Attempting to get information for venue with id =  4b800ce6f964a520cd4d30e3
# Attempting to get information for venue with id =  48e480eef964a52022521fe3
# Attempting to get information for venue with id =  43237380f964a520a6271fe3
# Attempting to get information for venue with id =  4a315675f964a520b2991fe3
# Attempting to get information for venue with id =  470f3ff0f964a5208e4b1fe3
# Attempting to get information for venue with id =  591a7894bd40092ec982b630
# Attempting to get information for venue with id =  56f247a7498e93a37ea880db
# Attempting to get information for venue with id =  3fd66200f964a520b6e71ee3
# Attempting to get information for venue with id =  565624fb498e83162d2bd21c
# Attempting to get information for venue with id =  435c2400f964a52012291fe3
# Attempting to get information for venue with id =  4a739322f964a520dbdc1fe3
# Attempting to get information for venue with id =  51d361d6498ea6250df6761d
# Attempting to get information for venue with id =  41f98080f964a5203a1f1fe3
# Attempting to get information for venue with id =  59d56267d8096e2ecd3187f1
# Attempting to get information for venue with id =  3fd66200f964a520aae31ee3
# Attempting to get information for venue with id =  4e8c7d54e5fa774802eb9515
# Attempting to get information for venue with id =  4161e400f964a520721d1fe3
# Attempting to get information for venue with id =  5202ca16498ef651c47e90b3
# Attempting to get information for venue with id =  4c7ecc952042b1f79b0dc1ad
# Attempting to get information for venue with id =  4459f9bff964a520e1321fe3
# Attempting to get information for venue with id =  4ff260e7e4b020c287b83193
# Attempting to get information for venue with id =  3fd66200f964a52000e71ee3
# Attempting to get information for venue with id =  4c22beee99282d7f17b667b0
# Attempting to get information for venue with id =  40e35400f964a520e6091fe3
# Attempting to get information for venue with id =  40a2ba80f964a520fef21ee3
# Attempting to get information for venue with id =  48f0fcdcf964a52041521fe3
# Attempting to get information for venue with id =  3fd66200f964a5203ee41ee3
# Attempting to get information for venue with id =  5cce2c2d0802d4002c446abb
# Attempting to get information for venue with id =  475847d3f964a520cb4c1fe3
# Attempting to get information for venue with id =  4fe2a8cfe4b019c9a5c3e4a2
# Attempting to get information for venue with id =  3fd66200f964a52005eb1ee3
# Attempting to get information for venue with id =  4a0b79cff964a520fc741fe3
# Attempting to get information for venue with id =  3fd66200f964a520e9e51ee3
# Attempting to get information for venue with id =  4eb1d6de4690370e0c5148d6
# Attempting to get information for venue with id =  4c47a87496abd13a66be7101
# Attempting to get information for venue with id =  4d901567c1b1721e8eb85446
# Attempting to get information for venue with id =  56e3c7c0498edc7faf82f5ac
# Attempting to get information for venue with id =  4e4f5b5952b1e893ad5a5392
# Attempting to get information for venue with id =  510b480ce4b005681df2cbfa
# Attempting to get information for venue with id =  5674d4ec498e0470007f431d
# Attempting to get information for venue with id =  56f78e1e498e40280bfc2eea
# Attempting to get information for venue with id =  4ba3225cf964a520162d38e3
# Attempting to get information for venue with id =  5b4fc2b467af3a002c9ab00f
# Attempting to get information for venue with id =  4bc40370461576b0ea777f32
# Attempting to get information for venue with id =  4e86924c61af043f1a3049dc
# Attempting to get information for venue with id =  59db9b2da5a315441774bf70
# Attempting to get information for venue with id =  4c397c5118e72d7f715e1af5
# Attempting to get information for venue with id =  50934a38e4b054dd3346160e
# Attempting to get information for venue with id =  4d8439daf9f3a1cd5e03b264
# Attempting to get information for venue with id =  4b65438ff964a52013eb2ae3
# Attempting to get information for venue with id =  4fed0388e4b08f8ae39994d0
# Attempting to get information for venue with id =  4c5e4e169b28d13a89425c70
# Attempting to get information for venue with id =  4dc7728bae608779d16c3358
# Attempting to get information for venue with id =  51ac180a498e83fcf1d990ed
# Attempting to get information for venue with id =  5a11f8d8d807ee612367136e
# Attempting to get information for venue with id =  4d6882829968236a0d3272a9
# Attempting to get information for venue with id =  57b310e5498e716658b70745
# Attempting to get information for venue with id =  4c2e5842452620a1fdac1b0f
# Attempting to get information for venue with id =  4e2f5d051f6ed9df901fba08
# Attempting to get information for venue with id =  50de6cfae4b03fabe221ebe6
# Attempting to get information for venue with id =  4f49df63e4b002a2ad066a81
# Attempting to get information for venue with id =  56609d3b498efe11e6679c4f
# Attempting to get information for venue with id =  510e34e891d4324491959af0
# Attempting to get information for venue with id =  4e20ec6c1838712abe6cc6da
# Attempting to get information for venue with id =  52e8a2ab11d23d68dd3809bc
# Attempting to get information for venue with id =  4d59c7bf8492a143aa8c2b27
# Attempting to get information for venue with id =  4dac64754df01c19b1b33010
# Attempting to get information for venue with id =  51184908e4b02c4e2f466278
# Attempting to get information for venue with id =  4fcbe260e4b039f7d4909f10
# Attempting to get information for venue with id =  4e499f9d18387418d6e4a69d
# Attempting to get information for venue with id =  4f442c35e4b093577f28c98c
# Attempting to get information for venue with id =  569624aa498e137c24568b48
# Attempting to get information for venue with id =  4d9fdcb1e8a6721e38de2ba5
# Attempting to get information for venue with id =  52771c8d498ed7d6bfb98ab5
# Attempting to get information for venue with id =  52e332f511d29d3e546c0398
# Attempting to get information for venue with id =  4f8f4fa1e4b096032fca9ee5
# Attempting to get information for venue with id =  4e1a753714957dc705eaeed6
# Attempting to get information for venue with id =  4c61c20ce1621b8d22d92153
# Attempting to get information for venue with id =  4cf46a2794feb1f7620728ba
# Attempting to get information for venue with id =  4b36c8c6f964a5205c3c25e3
# Attempting to get information for venue with id =  593b1aaf8e886a4603784cca
# Attempting to get information for venue with id =  4cc77e8dfa03224b61fe3eef
# Attempting to get information for venue with id =  531cda83498e12b2e204bd7d
# Attempting to get information for venue with id =  4e45738d52b1bac0d968b53f
# Attempting to get information for venue with id =  503897dce4b0307ba3371f3f
# Attempting to get information for venue with id =  51411f34e4b0dd075c56a02a
# Attempting to get information for venue with id =  4d819e23d95df04d967547bc
# Attempting to get information for venue with id =  4f8a26e2e4b0e67b85ceaadf
# Attempting to get information for venue with id =  4c8fcc280b9e37047558625e
# Attempting to get information for venue with id =  55987ba6498ebfe85091bdc3
# Attempting to get information for venue with id =  4c007ab38c1076b046462071
# Attempting to get information for venue with id =  4d094bc74adb3704fbcf0155
# Attempting to get information for venue with id =  4bcf9cb1a8b3a59347a4625f
# Attempting to get information for venue with id =  511a3d7ae4b0551202309239
# Attempting to get information for venue with id =  4cd040f32fd9b60cdf3c80eb
# Attempting to get information for venue with id =  4cc34b4b06c25481d1a68f47
# Attempting to get information for venue with id =  5699caf0498ebad99eeb5e6c
# Attempting to get information for venue with id =  4e0a4119aeb7a6da82841dfe
# Attempting to get information for venue with id =  5c450775a8eb60002cdb48cf
# Attempting to get information for venue with id =  4bb8115e7421a593cf7fc140
# Attempting to get information for venue with id =  568700a2498e3bf4ed3cb8c9
# Attempting to get information for venue with id =  4df1b584fa76abc3d8658c1d
# Attempting to get information for venue with id =  5b302aed610f04002c658478
# Attempting to get information for venue with id =  4e9f3620775ba9493a07ffd7
# Attempting to get information for venue with id =  4eb48503469073bbc5c3a1c3
# Attempting to get information for venue with id =  4db241618154eb510de658c3
# Attempting to get information for venue with id =  4e7d6ad646906ba64f22d9ed
# Attempting to get information for venue with id =  4f9d5dc9e4b06064303e7665
# Attempting to get information for venue with id =  4fb7149ae4b02db3077c0ef8
# Attempting to get information for venue with id =  522beb4c11d29afa62d45e16
# Attempting to get information for venue with id =  4c99607eeaa5a143c27cc3e4
# Attempting to get information for venue with id =  528430bb11d2e86d66f34065
# Attempting to get information for venue with id =  4f4f26f3e4b05c40d646c2a6
# Attempting to get information for venue with id =  4ce8e440d99f721e346cb373
# Attempting to get information for venue with id =  534392db498e631789f6eade
# Attempting to get information for venue with id =  4bca8c790687ef3b3c61dccc
# Attempting to get information for venue with id =  5394ef8f498e5e3ad1b348e7
# Attempting to get information for venue with id =  4dcf543aae603b786d47436a
# Attempting to get information for venue with id =  4d69de660a25b60cbed42a90
# Attempting to get information for venue with id =  4e61a1fe2271573ad7461f5d
# Attempting to get information for venue with id =  59bf2af435f9832f5b037d37
# Attempting to get information for venue with id =  4c92860b2bf7b60c7a57630a
# Attempting to get information for venue with id =  4bf1edf878cec928f104bb86
# Attempting to get information for venue with id =  50143148e4b06a7cdac10a5c
# Attempting to get information for venue with id =  4bf09fcf17880f47ea902937
# Attempting to get information for venue with id =  4ca7dc9cd250bfb7de2ec863
# Attempting to get information for venue with id =  57da0f88498e0dee5c0e75ee
# Attempting to get information for venue with id =  4d62f389939da14370091e1a
# Attempting to get information for venue with id =  4eda99300aaf49e029d9ac88
# Attempting to get information for venue with id =  4f9496c30cd6d5cd95df9c79
# Attempting to get information for venue with id =  4daf861781548efb15adcc94
# Attempting to get information for venue with id =  508376c5e4b0d2d664441bfa
# Attempting to get information for venue with id =  520ec70011d24f694e4718fb
# Attempting to get information for venue with id =  5181a92f498e18639802ebf7
# Attempting to get information for venue with id =  520ef8f311d22aa0673b35c4
# Attempting to get information for venue with id =  4ca6c662b7106dcb61cb61a5
# Attempting to get information for venue with id =  56075942498e9a253e73b484
# Attempting to get information for venue with id =  53ddc734498e59584bd091e8
# Attempting to get information for venue with id =  58c02d0155d62218350b722d
# Attempting to get information for venue with id =  4c89d17a3dc2a1cdf4b0a732
# Attempting to get information for venue with id =  4f2e9643e4b04297f86eab90
# Attempting to get information for venue with id =  508327ede4b052496592d151
# Attempting to get information for venue with id =  4f763f87e4b0d693680d9852
# Attempting to get information for venue with id =  4bca929d0687ef3b106cdccc
# Attempting to get information for venue with id =  4efb51d38231c11159ed56d3
# Attempting to get information for venue with id =  5810616238fa4b202d714977
# Attempting to get information for venue with id =  525b3afb11d25fdb73a45415
# Attempting to get information for venue with id =  4eaa7b63d3e3846cbca7ae12
# Attempting to get information for venue with id =  4fa43d61e4b0f90206868681
# Attempting to get information for venue with id =  4c6b4b09a48420a122ec090b
# Attempting to get information for venue with id =  5b5070437564f7002c42fd1e
# Attempting to get information for venue with id =  4c9582b858d4b60c1b693329
# Attempting to get information for venue with id =  4d7c3f8a7498a1cd03b67afc
# Attempting to get information for venue with id =  4d7eecc2cd09224b62395330
# Attempting to get information for venue with id =  4d1c88b48860a0933bf2bb34
# Attempting to get information for venue with id =  4ef53b2ab6342877b9155bc5
# Attempting to get information for venue with id =  4f4ecdc9e4b02966d3aef456
# Attempting to get information for venue with id =  597bbd459b04736052ebf3b3
# Attempting to get information for venue with id =  4d71b83e311f6ea8a70ed1ea
# Attempting to get information for venue with id =  4c146ec1a1010f47748a4c18
# Attempting to get information for venue with id =  50e78eace4b0a066927f2402
# Attempting to get information for venue with id =  4cdf7eb43644a093d411539f
# Attempting to get information for venue with id =  4e3157b5b0fb3ee646719122
# Attempting to get information for venue with id =  513c1984e4b0c0ddf5f0d567
# Attempting to get information for venue with id =  4ed977e030f83fb79b8b12be
# Attempting to get information for venue with id =  4cafd6d175ebb60c2dd6bfad
# Attempting to get information for venue with id =  4ed975b17ee56e58e64ac204
# Attempting to get information for venue with id =  4c92c546332c370406578b64
# Attempting to get information for venue with id =  4c6c0ad21fb2a1435450fae6
# Attempting to get information for venue with id =  50565f9fe4b06692140f3fa1
# Attempting to get information for venue with id =  4e335e1a45dd6987a1790c8f
# Attempting to get information for venue with id =  4f89d696e4b0b1c4b0267399
# Attempting to get information for venue with id =  52f707ac498e311715da45a9
# Attempting to get information for venue with id =  4e9a45d8d22d8be5890a0c42
# Attempting to get information for venue with id =  4cd0f49701eaf04de4dfbb5d
# Attempting to get information for venue with id =  5132dc0fe4b0a08cd4f2de0d
# Attempting to get information for venue with id =  4f3872dce4b0f4cfdfb0ee88
# Attempting to get information for venue with id =  4edb0ea79a5286d920332415
# Attempting to get information for venue with id =  55e120a8498eac393ea8d8d5
# Attempting to get information for venue with id =  500b7344e4b0a62ff4c02880
# Attempting to get information for venue with id =  4c82b64dd8086dcb02937952
# Attempting to get information for venue with id =  52c91abb498e029759200b51
# Attempting to get information for venue with id =  4cf20aab7e93f04dd5065169
# Attempting to get information for venue with id =  5346dcb2498e1590c030d5c6
# Attempting to get information for venue with id =  4d6dbf2f29586dcb974ba8f1
# Attempting to get information for venue with id =  52191d6b11d28ea50fefbd26
# Attempting to get information for venue with id =  4c80434ad4e237049a525388
# Attempting to get information for venue with id =  4eb9ea0c9a5284afea7b7021
# Attempting to get information for venue with id =  4dea2d36c65be8091d9ddb16
# Attempting to get information for venue with id =  4cdbeea9fc973704740ed205
# Attempting to get information for venue with id =  4c8ec6f658668cfaee02d5ec
# Attempting to get information for venue with id =  4ed06e399adf254456fc7b65
# Attempting to get information for venue with id =  4cf9bf3c2d80a143843a40d8
# Attempting to get information for venue with id =  5b3e9faa06fb60002cf1c8c8
# Attempting to get information for venue with id =  4b05f1b8f964a52053e622e3
# Attempting to get information for venue with id =  4ebdd2738b81127c0a44dd56
# Attempting to get information for venue with id =  4c65cee819f3c9b6593f9eff
# Attempting to get information for venue with id =  4e7157d1b0fb9f3b34c05743
# Attempting to get information for venue with id =  55b2f3b4498ee9feaca435b3
# Attempting to get information for venue with id =  523a7a6a11d202a57aac87c2
# Attempting to get information for venue with id =  4bca6355937ca59340dea792
# Attempting to get information for venue with id =  4c638fc6edd320a14cdbaf29
# Attempting to get information for venue with id =  4c26c29cc11dc9b696a22924
# Attempting to get information for venue with id =  4e278dfae4cd6c6cb33e86b8
# Attempting to get information for venue with id =  4f613d96e4b011d8506f6a2a
# Attempting to get information for venue with id =  4bfc0a4a6978d13ae870c7e7
# Attempting to get information for venue with id =  4f19fec3e4b0f271e527450f
# Attempting to get information for venue with id =  4c75f2f22db5236aa5a1be79
# Attempting to get information for venue with id =  4c2d6ccf3a4d0f47d6f3e386
# Attempting to get information for venue with id =  503bf68de4b0ee7fb00f1d3c
# Attempting to get information for venue with id =  4ed582850aaf6cc6c8bc332b
# Attempting to get information for venue with id =  4ee7fed28231d71b39510d37
# Attempting to get information for venue with id =  4d9a9a22335ab60c95f8e8f9
# Attempting to get information for venue with id =  5033108be4b04dcc1bbfbe93
# Attempting to get information for venue with id =  50a84bd2e4b0445d6690a5b4
# Attempting to get information for venue with id =  4f62908de4b0dc771e4f958f
# Attempting to get information for venue with id =  4bf74c51508c0f476b7c3d31
# Attempting to get information for venue with id =  4dbb12336e815ab0de621270
# Attempting to get information for venue with id =  50fb6e9de4b0d0486df4c1c0
# Attempting to get information for venue with id =  4f42d190e4b0f9c0eb0bb043
# Attempting to get information for venue with id =  4f092926e4b06fab1a0e0ce6
# Attempting to get information for venue with id =  4ff05070e4b0ef320d6096f3
# Attempting to get information for venue with id =  500f6748e4b00cb7c1120a4e
# Attempting to get information for venue with id =  51d90938498e124ecc4f4cf6
# Attempting to get information for venue with id =  4f32be6c19836c91c7f5b855
# Attempting to get information for venue with id =  4f3478c7e4b0aa1d1aa072bd
# Attempting to get information for venue with id =  4fff2d88e4b09d12b1167c6e
# Attempting to get information for venue with id =  50bb09cf29a6e1007eca2a18
# Attempting to get information for venue with id =  5ae4d757598e64002ceb5545
# Attempting to get information for venue with id =  508c52f6e4b0c9eb720644f3
# Attempting to get information for venue with id =  505ced00e4b0643aba448d76
# Attempting to get information for venue with id =  4cdf4f9af8a4a1432db6ddbc
# Attempting to get information for venue with id =  52ea09f411d2aa2b3c6b9ce0
# Attempting to get information for venue with id =  4f111aece4b0253d4c6377c6
# Attempting to get information for venue with id =  5312c1e2498ea8dfbe7ebeee
# Attempting to get information for venue with id =  517c695ee4b0f7d84b44b0c8
# Attempting to get information for venue with id =  4c9fa9c00e9bb1f77b7df25f
# Attempting to get information for venue with id =  4f6d4d28e4b0738fb21a2071
# Attempting to get information for venue with id =  4ec5aff8f79041351aa558c3
# Attempting to get information for venue with id =  4f93815de4b06ce8586591d5
# Attempting to get information for venue with id =  4eee47ea93add02fcd1e4d96
# Attempting to get information for venue with id =  4e9638a8cc21310d90240af6
# Attempting to get information for venue with id =  4f3449aee4b030798370d0b0
# Attempting to get information for venue with id =  4fed0030e4b0b6774ea0c87e
# Attempting to get information for venue with id =  4e45925345dd2955e58bc850
# Attempting to get information for venue with id =  4cbe54b200d8370494053d5c
# Attempting to get information for venue with id =  51ff6a40498ec390174c65f6
# Attempting to get information for venue with id =  5827a93a8e003314e048cf59
# Attempting to get information for venue with id =  4c0af7d4ffb8c9b6e8966c61
# Attempting to get information for venue with id =  4c51e23fb6dabe9aded87512
# Attempting to get information for venue with id =  4f605d66e4b0005743621044
# Attempting to get information for venue with id =  50fd7e38e4b0e6d7908ed885
# Attempting to get information for venue with id =  4f3dc8abe4b0f010501272a2
# Attempting to get information for venue with id =  51e23cef498e7b1ebc84fbe8
# Attempting to get information for venue with id =  4dd27f5c1f6ef5f6ccd5df9c
# Attempting to get information for venue with id =  4e30aff8b0fbb3b11125c89a
# Attempting to get information for venue with id =  4c9bee350e9bb1f7fb61cf5f
# Attempting to get information for venue with id =  569de7ca498ed6efc16e8445
# Attempting to get information for venue with id =  4fd2d969e4b0b31b8443b65e
# Attempting to get information for venue with id =  4fbe61247b0c49b697759ca9
# Attempting to get information for venue with id =  4f7f8158e4b04fb0c4150f7b
# Attempting to get information for venue with id =  51721df0e4b0d85983812c93
# Attempting to get information for venue with id =  573ab96a498ef31e9b16f56c
# Attempting to get information for venue with id =  547b764e498ea9baa90b9a3a
# Attempting to get information for venue with id =  4be08caa652b0f47ffcd7211
# Attempting to get information for venue with id =  4d636738d0c5a090b16f37e1
# Attempting to get information for venue with id =  4ca4202da73cb60cbdd81e78
# Attempting to get information for venue with id =  4f833e98e4b08807817dc0d3
# Attempting to get information for venue with id =  4b75fb83f964a52018342ee3
# Attempting to get information for venue with id =  5abeed8e3abcaf0cf64ae692
# Data Retrieval Complete

# %%
df.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Wakefield              40.894705              -73.847201
# 1    Wakefield              40.894705              -73.847201
# 2    Wakefield              40.894705              -73.847201
# 3    Wakefield              40.894705              -73.847201
# 4    Wakefield              40.894705              -73.847201
#
#                  Venue Name                  Venue ID Venue Category  \
# 0            The Upper Room  4f57ef61e4b063a4ab675858    Music Venue
# 1           Dyme Life Radio  4da63d645da3e8486b80546f    Music Venue
# 2                  Par-City  4d23aea014f2b1f7740f68be    Music Venue
# 3                 MY Studio  4e9cb64c49017c00c840e759    Music Venue
# 4  Major League Music Group  4ee0764f0aafbb3dbab41e92    Music Venue
#
#    Venue Latitude  Venue Longitude Venue City Venue State  Likes Rating
# 0       40.892567       -73.846406        NaN          NY    0.0    NaN
# 1       40.894541       -73.843266      Bronx          NY    0.0    NaN
# 2       40.890211       -73.847002      Bronx          NY    0.0    NaN
# 3       40.901926       -73.853504        NaN          NY    0.0    NaN
# 4       40.891367       -73.850088        NaN          NY    0.0    NaN

# %%
# Save as CSV
df.to_csv('Output/cleaned_venue_data2.csv', index = False)
